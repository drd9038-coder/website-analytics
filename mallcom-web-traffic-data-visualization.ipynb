# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#creating a table / matrix using python to plot graph
data=pd.DataFrame([[-16,-13,-11,-7],[-19,-15,-12,-9]], index=['ORGANIC TRAFFIC', 'ORGANIC NEW USERS'], columns=['Feb18 vs Jan18', 'Feb22 vs Jan222', 'Feb25 vs Jan25', 'Feb28 vs Jan28'])

# %%
data
# Out:
#                    Feb18 vs Jan18  Feb22 vs Jan222  Feb25 vs Jan25  \
# ORGANIC TRAFFIC               -16              -13             -11
# ORGANIC NEW USERS             -19              -15             -12
#
#                    Feb28 vs Jan28
# ORGANIC TRAFFIC                -7
# ORGANIC NEW USERS              -9

# %%
# now we shall plot a bar graph and a line graph

# %%
data.plot.barh()
# Out:
# <Axes: >

# %%
data
# Out:
#                    Feb18 vs Jan18  Feb22 vs Jan222  Feb25 vs Jan25  \
# ORGANIC TRAFFIC               -16              -13             -11
# ORGANIC NEW USERS             -19              -15             -12
#
#                    Feb28 vs Jan28
# ORGANIC TRAFFIC                -7
# ORGANIC NEW USERS              -9

# %%
#now we shall create a line plot
#we need to mention both x axis & y axis

# %%
x=['Feb18','Feb22','Feb25','Feb28']
y=[-16,-13,-11,-7]
plt.plot(x,y,'r*--')
plt.xlabel('dates')
plt.ylabel('organic traffic')
plt.title('improvement of organic traffic')
plt.savefig('organic_traffic.jpg')

# %%
x=['Feb18','Feb22','Feb25','Feb28']
y=[-19,-15,-12,-9]
plt.title('improvement of organic new users')
plt.xlabel('dates')
plt.ylabel('organic new users')
plt.plot(x,y,'b*--')
plt.savefig('organic_new_users.jpg')
